# %%
from deepface import DeepFace
import matplotlib.pyplot as plt

# %%
#!curl -o "oscars_show.jpg" "https://ca-times.brightspotcdn.com/dims4/default/b4bba04/2147483647/strip/true/crop/6000x4000+0+0/resize/1200x800!/format/webp/quality/75/?url=https%3A%2F%2Fcalifornia-times-brightspot.s3.amazonaws.com%2F39%2F4e%2F7dd46b804e6e85140eaf9b0f682e%2F1496586-et-oscars-show-4612.jpg"

# %%
path = "01_ImgEjemplos/oscars_show.jpg"

fig = plt.figure(figsize=(10,10))
img = plt.imread(path)
plt.imshow(img)

# %%
faces = DeepFace.extract_faces(img_path = path)

# %%
len(faces)
# Out:
# 11

# %%
for face in faces:
    plt.imshow(face["face"])
    plt.axis("off")
    plt.show()
