# %%
from deepface import DeepFace
# Out:
# WARNING:tensorflow:From c:\Users\manue\anaconda3\envs\UP\Lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# 25-10-10 12:05:46 - Directory C:\Users\manue\.deepface has been created
# 25-10-10 12:05:46 - Directory C:\Users\manue\.deepface\weights has been created

# %%
result = DeepFace.verify(
    img1_path = "Angelina_Jolie/AngelinaJolie1.jpg",
    img2_path = "Angelina_Jolie/AngelinaJolie2.jpg",
)
result
# Out:
# 25-10-10 12:05:47 - 🔗 vgg_face_weights.h5 will be downloaded from https://github.com/serengil/deepface_models/releases/download/v1.0/vgg_face_weights.h5 to C:\Users\manue\.deepface\weights\vgg_face_weights.h5...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/vgg_face_weights.h5
# To: C:\Users\manue\.deepface\weights\vgg_face_weights.h5
# 100%|██████████| 580M/580M [00:24<00:00, 24.1MB/s]
# {'verified': True,
#  'distance': 0.409192,
#  'threshold': 0.68,
#  'confidence': 80.06,
#  'model': 'VGG-Face',
#  'detector_backend': 'opencv',
#  'similarity_metric': 'cosine',
#  'facial_areas': {'img1': {'x': 697,
#    'y': 140,
#    'w': 505,
#    'h': 505,
#    'left_eye': (1043, 333),
#    'right_eye': (848, 339)},
#   'img2': {'x': 416,
#    'y': 239,
#    'w': 525,
#    'h': 525,
#    'left_eye': (773, 437),
#    'right_eye': (576, 445)}},
#  'time': 33.64}

# %%
img1_path = "Angelina_Jolie/AngelinaJolie1.jpg"
img2_path = "Angelina_Jolie/AngelinaJolie2.jpg"

DeepFace.verify(img1_path, img2_path, model_name="Facenet")
# Out:
# 25-10-10 12:06:25 - 🔗 facenet_weights.h5 will be downloaded from https://github.com/serengil/deepface_models/releases/download/v1.0/facenet_weights.h5 to C:\Users\manue\.deepface\weights\facenet_weights.h5...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/facenet_weights.h5
# To: C:\Users\manue\.deepface\weights\facenet_weights.h5
# 100%|██████████| 92.2M/92.2M [00:03<00:00, 30.1MB/s]
# {'verified': True,
#  'distance': 0.231841,
#  'threshold': 0.4,
#  'confidence': 77.02,
#  'model': 'Facenet',
#  'detector_backend': 'opencv',
#  'similarity_metric': 'cosine',
#  'facial_areas': {'img1': {'x': 697,
#    'y': 140,
#    'w': 505,
#    'h': 505,
#    'left_eye': (1043, 333),
#    'right_eye': (848, 339)},
#   'img2': {'x': 416,
#    'y': 239,
#    'w': 525,
#    'h': 525,
#    'left_eye': (773, 437),
#    'right_eye': (576, 445)}},
#  'time': 19.1}

# %%
#DeepFace.verify?

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
img1_path = "Angelina_Jolie/AngelinaJolie1.jpg"
img2_path = "Angelina_Jolie/AngelinaJolie2.jpg"

# %%
img1 = plt.imread(img1_path)
img2 = plt.imread(img2_path)

plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.imshow(img1)
plt.subplot(1, 2, 2)
plt.imshow(img2)
img1.shape, img2.shape
# Out:
# ((1080, 1920, 3), (1604, 1200, 3))

# %%
img1_faces = DeepFace.extract_faces(img1_path)
img2_faces = DeepFace.extract_faces(img2_path)

img1 = img1_faces[0]["face"]
img2 = img2_faces[0]["face"]
print(img1.shape)

fig = plt.figure(figsize=(10,5))
fig.add_subplot(1,2,1)
plt.imshow(img1)
fig.add_subplot(1,2,2)
plt.imshow(img2)
# Out:
# (505, 505, 3)

# %%
img1 = img1_faces[0]["face"]
img2 = img1_faces[1]["face"]


fig = plt.figure(figsize=(10,5))
fig.add_subplot(1,2,1)
plt.imshow(img1)
fig.add_subplot(1,2,2)
plt.imshow(img2)

# %%
model_name = "VGG-Face"
resp = DeepFace.verify(img1_path, img2_path, model_name = model_name)
resp
# Out:
# {'verified': True,
#  'distance': 0.409192,
#  'threshold': 0.68,
#  'confidence': 80.06,
#  'model': 'VGG-Face',
#  'detector_backend': 'opencv',
#  'similarity_metric': 'cosine',
#  'facial_areas': {'img1': {'x': 697,
#    'y': 140,
#    'w': 505,
#    'h': 505,
#    'left_eye': (1043, 333),
#    'right_eye': (848, 339)},
#   'img2': {'x': 416,
#    'y': 239,
#    'w': 525,
#    'h': 525,
#    'left_eye': (773, 437),
#    'right_eye': (576, 445)}},
#  'time': 1.1}

# %%
model_name = "Facenet"
resp2 = DeepFace.verify(img1_path, img2_path, model_name = model_name)
resp2
# Out:
# {'verified': True,
#  'distance': 0.231841,
#  'threshold': 0.4,
#  'confidence': 77.02,
#  'model': 'Facenet',
#  'detector_backend': 'opencv',
#  'similarity_metric': 'cosine',
#  'facial_areas': {'img1': {'x': 697,
#    'y': 140,
#    'w': 505,
#    'h': 505,
#    'left_eye': (1043, 333),
#    'right_eye': (848, 339)},
#   'img2': {'x': 416,
#    'y': 239,
#    'w': 525,
#    'h': 525,
#    'left_eye': (773, 437),
#    'right_eye': (576, 445)}},
#  'time': 1.77}

# %%
model_name = "GhostFaceNet"
resp2 = DeepFace.verify(img1_path, img2_path,model_name=model_name)
resp2
# Out:
# 25-10-10 12:06:49 - 🔗 ghostfacenet_v1.h5 will be downloaded from https://github.com/HamadYA/GhostFaceNets/releases/download/v1.2/GhostFaceNet_W1.3_S1_ArcFace.h5 to C:\Users\manue\.deepface\weights\ghostfacenet_v1.h5...
# Downloading...
# From: https://github.com/HamadYA/GhostFaceNets/releases/download/v1.2/GhostFaceNet_W1.3_S1_ArcFace.h5
# To: C:\Users\manue\.deepface\weights\ghostfacenet_v1.h5
# 100%|██████████| 17.3M/17.3M [00:00<00:00, 20.7MB/s]
# {'verified': True,
#  'distance': 0.408401,
#  'threshold': 0.65,
#  'confidence': 74.31,
#  'model': 'GhostFaceNet',
#  'detector_backend': 'opencv',
#  'similarity_metric': 'cosine',
#  'facial_areas': {'img1': {'x': 697,
#    'y': 140,
#    'w': 505,
#    'h': 505,
#    'left_eye': (1043, 333),
#    'right_eye': (848, 339)},
#   'img2': {'x': 416,
#    'y': 239,
#    'w': 525,
#    'h': 525,
#    'left_eye': (773, 437),
#    'right_eye': (576, 445)}},
#  'time': 7.53}

# %%
model_name = "Facenet512"
resp2 = DeepFace.verify(img1_path, img2_path,model_name=model_name)
resp2
# Out:
# 25-10-10 12:06:56 - 🔗 facenet512_weights.h5 will be downloaded from https://github.com/serengil/deepface_models/releases/download/v1.0/facenet512_weights.h5 to C:\Users\manue\.deepface\weights\facenet512_weights.h5...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/facenet512_weights.h5
# To: C:\Users\manue\.deepface\weights\facenet512_weights.h5
# 100%|██████████| 95.0M/95.0M [00:03<00:00, 25.9MB/s]
# {'verified': True,
#  'distance': 0.232137,
#  'threshold': 0.3,
#  'confidence': 65.56,
#  'model': 'Facenet512',
#  'detector_backend': 'opencv',
#  'similarity_metric': 'cosine',
#  'facial_areas': {'img1': {'x': 697,
#    'y': 140,
#    'w': 505,
#    'h': 505,
#    'left_eye': (1043, 333),
#    'right_eye': (848, 339)},
#   'img2': {'x': 416,
#    'y': 239,
#    'w': 525,
#    'h': 525,
#    'left_eye': (773, 437),
#    'right_eye': (576, 445)}},
#  'time': 11.47}

# %%
#DeepFace.verify?
#info = DeepFace.verify.__doc__
#posi = info.find("Options:")
#posf = info[posi:].find(".")
#model_options = info[posi:posi+posf]
#print(model_options)

# %%
model_names = "VGG-Face, Facenet, Facenet512, OpenFace, DeepID, ArcFace, SFace, GhostFaceNet".split(", ")  
model_names
# Out:
# ['VGG-Face',
#  'Facenet',
#  'Facenet512',
#  'OpenFace',
#  'DeepID',
#  'ArcFace',
#  'SFace',
#  'GhostFaceNet']

# %%
for model_name in model_names:
    print(model_name)
    resp = DeepFace.verify(img1_path, img2_path,model_name=model_name)
    print(resp)
    print("-"*50)
# Out:
# VGG-Face
# {'verified': True, 'distance': 0.409192, 'threshold': 0.68, 'confidence': 80.06, 'model': 'VGG-Face', 'detector_backend': 'opencv', 'similarity_metric': 'cosine', 'facial_areas': {'img1': {'x': 697, 'y': 140, 'w': 505, 'h': 505, 'left_eye': (1043, 333), 'right_eye': (848, 339)}, 'img2': {'x': 416, 'y': 239, 'w': 525, 'h': 525, 'left_eye': (773, 437), 'right_eye': (576, 445)}}, 'time': 1.28}
# --------------------------------------------------
# Facenet
# {'verified': True, 'distance': 0.231841, 'threshold': 0.4, 'confidence': 77.02, 'model': 'Facenet', 'detector_backend': 'opencv', 'similarity_metric': 'cosine', 'facial_areas': {'img1': {'x': 697, 'y': 140, 'w': 505, 'h': 505, 'left_eye': (1043, 333), 'right_eye': (848, 339)}, 'img2': {'x': 416, 'y': 239, 'w': 525, 'h': 525, 'left_eye': (773, 437), 'right_eye': (576, 445)}}, 'time': 2.93}
# --------------------------------------------------
# Facenet512
# {'verified': True, 'distance': 0.232137, 'threshold': 0.3, 'confidence': 65.56, 'model': 'Facenet512', 'detector_backend': 'opencv', 'similarity_metric': 'cosine', 'facial_areas': {'img1': {'x': 697, 'y': 140, 'w': 505, 'h': 505, 'left_eye': (1043, 333), 'right_eye': (848, 339)}, 'img2': {'x': 416, 'y': 239, 'w': 525, 'h': 525, 'left_eye': (773, 437), 'right_eye': (576, 445)}}, 'time': 2.55}
# --------------------------------------------------
# OpenFace
# 25-10-10 12:07:13 - 🔗 openface_weights.h5 will be downloaded from https://github.com/serengil/deepface_models/releases/download/v1.0/openface_weights.h5 to C:\Users\manue\.deepface\weights\openface_weights.h5...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/openface_weights.h5
# To: C:\Users\manue\.deepface\weights\openface_weights.h5
# 100%|██████████| 15.3M/15.3M [00:01<00:00, 9.37MB/s]
# {'verified': True, 'distance': 0.08703, 'threshold': 0.1, 'confidence': 55.83, 'model': 'OpenFace', 'detector_backend': 'opencv', 'similarity_metric': 'cosine', 'facial_areas': {'img1': {'x': 697, 'y': 140, 'w': 505, 'h': 505, 'left_eye': (1043, 333), 'right_eye': (848, 339)}, 'img2': {'x': 416, 'y': 239, 'w': 525, 'h': 525, 'left_eye': (773, 437), 'right_eye': (576, 445)}}, 'time': 6.24}
# --------------------------------------------------
# DeepID
# 25-10-10 12:07:17 - 🔗 deepid_keras_weights.h5 will be downloaded from https://github.com/serengil/deepface_models/releases/download/v1.0/deepid_keras_weights.h5 to C:\Users\manue\.deepface\weights\deepid_keras_weights.h5...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/deepid_keras_weights.h5
# To: C:\Users\manue\.deepface\weights\deepid_keras_weights.h5
# 100%|██████████| 1.61M/1.61M [00:00<00:00, 6.26MB/s]
# {'verified': False, 'distance': 0.018931, 'threshold': 0.015, 'confidence': 15.46, 'model': 'DeepID', 'detector_backend': 'opencv', 'similarity_metric': 'cosine', 'facial_areas': {'img1': {'x': 697, 'y': 140, 'w': 505, 'h': 505, 'left_eye': (1043, 333), 'right_eye': (848, 339)}, 'img2': {'x': 416, 'y': 239, 'w': 525, 'h': 525, 'left_eye': (773, 437), 'right_eye': (576, 445)}}, 'time': 2.27}
# --------------------------------------------------
# ArcFace
# 25-10-10 12:07:22 - 🔗 arcface_weights.h5 will be downloaded from https://github.com/serengil/deepface_models/releases/download/v1.0/arcface_weights.h5 to C:\Users\manue\.deepface\weights\arcface_weights.h5...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/arcface_weights.h5
# To: C:\Users\manue\.deepface\weights\arcface_weights.h5
# 100%|██████████| 137M/137M [00:21<00:00, 6.32MB/s]
# {'verified': True, 'distance': 0.47947, 'threshold': 0.68, 'confidence': 63.2, 'model': 'ArcFace', 'detector_backend': 'opencv', 'similarity_metric': 'cosine', 'facial_areas': {'img1': {'x': 697, 'y': 140, 'w': 505, 'h': 505, 'left_eye': (1043, 333), 'right_eye': (848, 339)}, 'img2': {'x': 416, 'y': 239, 'w': 525, 'h': 525, 'left_eye': (773, 437), 'right_eye': (576, 445)}}, 'time': 26.54}
# --------------------------------------------------
# SFace
# 25-10-10 12:07:46 - 🔗 face_recognition_sface_2021dec.onnx will be downloaded from https://github.com/opencv/opencv_zoo/raw/main/models/face_recognition_sface/face_recognition_sface_2021dec.onnx to C:\Users\manue\.deepface\weights\face_recognition_sface_2021dec.onnx...
# Downloading...
# From: https://github.com/opencv/opencv_zoo/raw/main/models/face_recognition_sface/face_recognition_sface_2021dec.onnx
# To: C:\Users\manue\.deepface\weights\face_recognition_sface_2021dec.onnx
# 100%|██████████| 38.7M/38.7M [00:05<00:00, 7.03MB/s]
# {'verified': True, 'distance': 0.353185, 'threshold': 0.593, 'confidence': 76.94, 'model': 'SFace', 'detector_backend': 'opencv', 'similarity_metric': 'cosine', 'facial_areas': {'img1': {'x': 697, 'y': 140, 'w': 505, 'h': 505, 'left_eye': (1043, 333), 'right_eye': (848, 339)}, 'img2': {'x': 416, 'y': 239, 'w': 525, 'h': 525, 'left_eye': (773, 437), 'right_eye': (576, 445)}}, 'time': 7.86}
# --------------------------------------------------
# GhostFaceNet
# {'verified': True, 'distance': 0.408401, 'threshold': 0.65, 'confidence': 74.31, 'model': 'GhostFaceNet', 'detector_backend': 'opencv', 'similarity_metric': 'cosine', 'facial_areas': {'img1': {'x': 697, 'y': 140, 'w': 505, 'h': 505, 'left_eye': (1043, 333), 'right_eye': (848, 339)}, 'img2': {'x': 416, 'y': 239, 'w': 525, 'h': 525, 'left_eye': (773, 437), 'right_eye': (576, 445)}}, 'time': 1.45}
# --------------------------------------------------

# %%
def graficar (img1,img2):
    fig = plt.figure()
    fig.add_subplot(1,2,1)
    plt.imshow(img1)
    fig.add_subplot(1,2,2)
    plt.imshow(img2)

# %%
folder_path = "Keira_Knightley"
img1_path = f"{folder_path}/img0.jpg"
img2_path = f"{folder_path}/img1.jpg"
#img2_path = f"{folder_path}/img2.jpg" #error Please confirm that the picture is a face photo or consider to set enforce_detection param to False.
model_name = "Facenet"

img1 = DeepFace.extract_faces(img1_path)
img2 = DeepFace.extract_faces(img2_path)
graficar(img1[0]["face"],img2[0]["face"])

resp = DeepFace.verify(img1_path, img2_path,model_name=model_name)
resp
# Out:
# {'verified': True,
#  'distance': 0.346295,
#  'threshold': 0.4,
#  'confidence': 55.92,
#  'model': 'Facenet',
#  'detector_backend': 'opencv',
#  'similarity_metric': 'cosine',
#  'facial_areas': {'img1': {'x': 249,
#    'y': 230,
#    'w': 393,
#    'h': 393,
#    'left_eye': (516, 384),
#    'right_eye': (370, 381)},
#   'img2': {'x': 833,
#    'y': 328,
#    'w': 285,
#    'h': 285,
#    'left_eye': (1026, 433),
#    'right_eye': (913, 435)}},
#  'time': 1.35}

# %%
folder_path = "Natalie_Portman"
img1_path = f"{folder_path}/img0.jpg"
img2_path = f"{folder_path}/img2.jpg"
model_name = "Facenet"

img1 = DeepFace.extract_faces(img1_path)
img2 = DeepFace.extract_faces(img2_path)
graficar(img1[0]["face"],img2[0]["face"])

resp = DeepFace.verify(img1_path, img2_path,model_name=model_name)
resp
# Out:
# {'verified': True,
#  'distance': 0.345962,
#  'threshold': 0.4,
#  'confidence': 55.98,
#  'model': 'Facenet',
#  'detector_backend': 'opencv',
#  'similarity_metric': 'cosine',
#  'facial_areas': {'img1': {'x': 944,
#    'y': 614,
#    'w': 995,
#    'h': 995,
#    'left_eye': (1606, 988),
#    'right_eye': (1252, 1008)},
#   'img2': {'x': 264,
#    'y': 41,
#    'w': 108,
#    'h': 108,
#    'left_eye': (337, 83),
#    'right_eye': (296, 83)}},
#  'time': 2.38}

# %%
folder_path = "Natalie_Portman"
img1_path = f"{folder_path}/img0.jpg"

folder_path = "Keira_Knightley"
img2_path = f"{folder_path}/img1.jpg"

img1 = DeepFace.extract_faces(img1_path)
img2 = DeepFace.extract_faces(img2_path)
graficar(img1[0]["face"],img2[0]["face"])

model_name = "Facenet"
resp = DeepFace.verify(img1_path, img2_path,model_name=model_name)
resp
# Out:
# {'verified': False,
#  'distance': 0.594068,
#  'threshold': 0.4,
#  'confidence': 17.81,
#  'model': 'Facenet',
#  'detector_backend': 'opencv',
#  'similarity_metric': 'cosine',
#  'facial_areas': {'img1': {'x': 944,
#    'y': 614,
#    'w': 995,
#    'h': 995,
#    'left_eye': (1606, 988),
#    'right_eye': (1252, 1008)},
#   'img2': {'x': 833,
#    'y': 328,
#    'w': 285,
#    'h': 285,
#    'left_eye': (1026, 433),
#    'right_eye': (913, 435)}},
#  'time': 2.32}

# %%
folder_path = "Natalie_Portman"
img1_path = f"{folder_path}/img0.jpg"

folder_path = "Keira_Knightley"
img2_path = f"{folder_path}/img1.jpg"


for model_name in model_names:
    print(model_name)
    resp = DeepFace.verify(img1_path, img2_path,model_name=model_name)
    print(resp)
    print("-"*50)
# Out:
# VGG-Face
# {'verified': True, 'distance': 0.593118, 'threshold': 0.68, 'confidence': 58.78, 'model': 'VGG-Face', 'detector_backend': 'opencv', 'similarity_metric': 'cosine', 'facial_areas': {'img1': {'x': 944, 'y': 614, 'w': 995, 'h': 995, 'left_eye': (1606, 988), 'right_eye': (1252, 1008)}, 'img2': {'x': 833, 'y': 328, 'w': 285, 'h': 285, 'left_eye': (1026, 433), 'right_eye': (913, 435)}}, 'time': 2.17}
# --------------------------------------------------
# Facenet
# {'verified': False, 'distance': 0.594068, 'threshold': 0.4, 'confidence': 17.81, 'model': 'Facenet', 'detector_backend': 'opencv', 'similarity_metric': 'cosine', 'facial_areas': {'img1': {'x': 944, 'y': 614, 'w': 995, 'h': 995, 'left_eye': (1606, 988), 'right_eye': (1252, 1008)}, 'img2': {'x': 833, 'y': 328, 'w': 285, 'h': 285, 'left_eye': (1026, 433), 'right_eye': (913, 435)}}, 'time': 2.28}
# --------------------------------------------------
# Facenet512
# {'verified': False, 'distance': 0.578776, 'threshold': 0.3, 'confidence': 16.6, 'model': 'Facenet512', 'detector_backend': 'opencv', 'similarity_metric': 'cosine', 'facial_areas': {'img1': {'x': 944, 'y': 614, 'w': 995, 'h': 995, 'left_eye': (1606, 988), 'right_eye': (1252, 1008)}, 'img2': {'x': 833, 'y': 328, 'w': 285, 'h': 285, 'left_eye': (1026, 433), 'right_eye': (913, 435)}}, 'time': 2.42}
# --------------------------------------------------
# OpenFace
# {'verified': False, 'distance': 0.127194, 'threshold': 0.1, 'confidence': 8.03, 'model': 'OpenFace', 'detector_backend': 'opencv', 'similarity_metric': 'cosine', 'facial_areas': {'img1': {'x': 944, 'y': 614, 'w': 995, 'h': 995, 'left_eye': (1606, 988), 'right_eye': (1252, 1008)}, 'img2': {'x': 833, 'y': 328, 'w': 285, 'h': 285, 'left_eye': (1026, 433), 'right_eye': (913, 435)}}, 'time': 1.95}
# --------------------------------------------------
# DeepID
# {'verified': False, 'distance': 0.026989, 'threshold': 0.015, 'confidence': 14.41, 'model': 'DeepID', 'detector_backend': 'opencv', 'similarity_metric': 'cosine', 'facial_areas': {'img1': {'x': 944, 'y': 614, 'w': 995, 'h': 995, 'left_eye': (1606, 988), 'right_eye': (1252, 1008)}, 'img2': {'x': 833, 'y': 328, 'w': 285, 'h': 285, 'left_eye': (1026, 433), 'right_eye': (913, 435)}}, 'time': 1.82}
# --------------------------------------------------
# ArcFace
# {'verified': False, 'distance': 0.811943, 'threshold': 0.68, 'confidence': 10.27, 'model': 'ArcFace', 'detector_backend': 'opencv', 'similarity_metric': 'cosine', 'facial_areas': {'img1': {'x': 944, 'y': 614, 'w': 995, 'h': 995, 'left_eye': (1606, 988), 'right_eye': (1252, 1008)}, 'img2': {'x': 833, 'y': 328, 'w': 285, 'h': 285, 'left_eye': (1026, 433), 'right_eye': (913, 435)}}, 'time': 2.15}
# --------------------------------------------------
# SFace
# {'verified': True, 'distance': 0.425281, 'threshold': 0.593, 'confidence': 67.79, 'model': 'SFace', 'detector_backend': 'opencv', 'similarity_metric': 'cosine', 'facial_areas': {'img1': {'x': 944, 'y': 614, 'w': 995, 'h': 995, 'left_eye': (1606, 988), 'right_eye': (1252, 1008)}, 'img2': {'x': 833, 'y': 328, 'w': 285, 'h': 285, 'left_eye': (1026, 433), 'right_eye': (913, 435)}}, 'time': 1.8}
# --------------------------------------------------
# GhostFaceNet
# {'verified': False, 'distance': 0.788857, 'threshold': 0.65, 'confidence': 10.62, 'model': 'GhostFaceNet', 'detector_backend': 'opencv', 'similarity_metric': 'cosine', 'facial_areas': {'img1': {'x': 944, 'y': 614, 'w': 995, 'h': 995, 'left_eye': (1606, 988), 'right_eye': (1252, 1008)}, 'img2': {'x': 833, 'y': 328, 'w': 285, 'h': 285, 'left_eye': (1026, 433), 'right_eye': (913, 435)}}, 'time': 2.46}
# --------------------------------------------------

# %%
img1 = DeepFace.extract_faces(img1_path)
img2 = DeepFace.extract_faces(img2_path)
graficar(img1[0]["face"],img2[0]["face"])

# %%
folder_path = "Natalie_Portman"
img1_path = f"{folder_path}/img2.jpg"

folder_path = "Keira_Knightley"
img2_path = f"{folder_path}/img1.jpg"

img1 = DeepFace.extract_faces(img1_path)
img2 = DeepFace.extract_faces(img2_path)

fig = plt.figure(figsize=(10, 10))

plt.subplot(1, 2, 1)
plt.imshow(img1[0]["face"])

plt.subplot(1, 2, 2)
plt.imshow(img2[0]["face"])

model_name = "Facenet"
resp = DeepFace.verify(img1_path, img2_path,model_name=model_name)
print(resp)
# Out:
# {'verified': False, 'distance': 0.556194, 'threshold': 0.4, 'confidence': 21.14, 'model': 'Facenet', 'detector_backend': 'opencv', 'similarity_metric': 'cosine', 'facial_areas': {'img1': {'x': 264, 'y': 41, 'w': 108, 'h': 108, 'left_eye': (337, 83), 'right_eye': (296, 83)}, 'img2': {'x': 833, 'y': 328, 'w': 285, 'h': 285, 'left_eye': (1026, 433), 'right_eye': (913, 435)}}, 'time': 1.32}

# %%
import pandas as pd

# %%
model_names
# Out:
# ['VGG-Face',
#  'Facenet',
#  'Facenet512',
#  'OpenFace',
#  'DeepID',
#  'ArcFace',
#  'SFace',
#  'GhostFaceNet']

# %%
img_path_source = "Angelina_Jolie/AngelinaJolie1.jpg"
db_path = "Dataset"
resp = DeepFace.find(img_path_source, db_path, model_name = model_names[0])
resp
# Out:
# 25-10-10 12:08:30 - Found 6 newly added image(s), 6 removed image(s), 0 replaced image(s).
# Finding representations: 100%|██████████| 6/6 [00:03<00:00,  1.69it/s]
# 25-10-10 12:08:33 - There are now 6 representations in ds_model_vggface_detector_opencv_aligned_normalization_base_expand_0.pkl
# 25-10-10 12:08:33 - Searching Angelina_Jolie/AngelinaJolie1.jpg in 6 length datastore
# 25-10-10 12:08:34 - find function duration 4.187952518463135 seconds
# [                     identity                                      hash  \
#  0  Dataset\AngelinaJolie2.jpg  9eef67c5a9f899e884a3c9d61c6bad285931c9cb
#
#     target_x  target_y  target_w  target_h  threshold  source_x  source_y  \
#  0       416       239       525       525       0.68       697       140
#
#     source_w  source_h  distance  confidence
#  0       505       505  0.432847       77.31  ,
#                             identity                                      hash  \
#  0  Dataset\Natalie_Portman_img1.jpg  d59eae5caca1a8c09b75f0c36be56cb6c70f6fee
#
#     target_x  target_y  target_w  target_h  threshold  source_x  source_y  \
#  0       681       323       377       377       0.68       802       570
#
#     source_w  source_h  distance  confidence
#  0       225       225   0.56682       61.59  ]

# %%
df = pd.concat(resp, ignore_index=True)
df
# Out:
#                            identity                                      hash  \
# 0        Dataset\AngelinaJolie2.jpg  9eef67c5a9f899e884a3c9d61c6bad285931c9cb
# 1  Dataset\Natalie_Portman_img1.jpg  d59eae5caca1a8c09b75f0c36be56cb6c70f6fee
#
#    target_x  target_y  target_w  target_h  threshold  source_x  source_y  \
# 0       416       239       525       525       0.68       697       140
# 1       681       323       377       377       0.68       802       570
#
#    source_w  source_h  distance  confidence
# 0       505       505  0.432847       77.31
# 1       225       225  0.566820       61.59

# %%
DeepFace.analyze(img_path_source, actions = ['age'])
#DeepFace.analyze(img_path_source)
# Out:
# 25-10-10 12:08:35 - 🔗 age_model_weights.h5 will be downloaded from https://github.com/serengil/deepface_models/releases/download/v1.0/age_model_weights.h5 to C:\Users\manue\.deepface\weights\age_model_weights.h5...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/age_model_weights.h5
# To: C:\Users\manue\.deepface\weights\age_model_weights.h5
# 100%|██████████| 539M/539M [00:24<00:00, 21.6MB/s]
# [{'age': 31,
#   'region': {'x': 697,
#    'y': 140,
#    'w': 505,
#    'h': 505,
#    'left_eye': (1043, 333),
#    'right_eye': (848, 339)},
#   'face_confidence': 0.92},
#  {'age': 25,
#   'region': {'x': 802,
#    'y': 570,
#    'w': 225,
#    'h': 225,
#    'left_eye': None,
#    'right_eye': None},
#   'face_confidence': 0.96}]

# %%
DeepFace.analyze(img_path_source, actions = ["emotion", "age", "gender", "race"])
# Out:
# Action: emotion:   0%|          | 0/4 [00:00<?, ?it/s]
# 25-10-10 12:09:02 - 🔗 facial_expression_model_weights.h5 will be downloaded from https://github.com/serengil/deepface_models/releases/download/v1.0/facial_expression_model_weights.h5 to C:\Users\manue\.deepface\weights\facial_expression_model_weights.h5...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/facial_expression_model_weights.h5
# To: C:\Users\manue\.deepface\weights\facial_expression_model_weights.h5
# 100%|██████████| 5.98M/5.98M [00:00<00:00, 14.5MB/s]
# Action: gender:  50%|█████     | 2/4 [00:01<00:01,  1.76it/s]
# 25-10-10 12:09:04 - 🔗 gender_model_weights.h5 will be downloaded from https://github.com/serengil/deepface_models/releases/download/v1.0/gender_model_weights.h5 to C:\Users\manue\.deepface\weights\gender_model_weights.h5...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/gender_model_weights.h5
# To: C:\Users\manue\.deepface\weights\gender_model_weights.h5
# 100%|██████████| 537M/537M [01:41<00:00, 5.31MB/s]
# Action: race:  75%|███████▌  | 3/4 [01:44<00:47, 47.43s/it]
# 25-10-10 12:10:47 - 🔗 race_model_single_batch.h5 will be downloaded from https://github.com/serengil/deepface_models/releases/download/v1.0/race_model_single_batch.h5 to C:\Users\manue\.deepface\weights\race_model_single_batch.h5...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/race_model_single_batch.h5
# To: C:\Users\manue\.deepface\weights\race_model_single_batch.h5
# 100%|██████████| 537M/537M [00:18<00:00, 29.8MB/s]
# Action: race: 100%|██████████| 4/4 [02:04<00:00, 31.20s/it]
# Action: race: 100%|██████████| 4/4 [00:00<00:00,  7.35it/s]
# [{'emotion': {'angry': np.float32(0.4144682),
#    'disgust': np.float32(0.0025924717),
#    'fear': np.float32(0.4788495),
#    'happy': np.float32(29.804405),
#    'sad': np.float32(2.8687127),
#    'surprise': np.float32(0.14808226),
#    'neutral': np.float32(66.28289)},
#   'dominant_emotion': 'neutral',
#   'region': {'x': 697,
#    'y': 140,
#    'w': 505,
#    'h': 505,
#    'left_eye': (1043, 333),
#    'right_eye': (848, 339)},
#   'face_confidence': 0.92,
#   'age': 31,
#   'gender': {'Woman': np.float32(99.99996), 'Man': np.float32(3.4407884e-05)},
#   'dominant_gender': 'Woman',
#   'race': {'asian': np.float32(0.014379396),
#    'indian': np.float32(0.07667757),
#    'black': np.float32(0.0005313523),
#    'white': np.float32(86.73685),
#    'middle eastern': np.float32(11.096027),
#    'latino hispanic': np.float32(2.0755436)},
#   'dominant_race': 'white'},
#  {'emotion': {'angry': np.float32(73.15937),
#    'disgust': np.float32(1.8509088e-07),
#    'fear': np.float32(0.22026622),
#    'happy': np.float32(0.00321551),
#    'sad': np.float32(17.611166),
#    'surprise': np.float32(0.00010343636),
#    'neutral': np.float32(9.005881)},
#   'dominant_emotion': 'angry',
#   'region': {'x': 802,
#    'y': 570,
#    'w': 225,
#    'h': 225,
#    'left_eye': None,
#    'right_eye': None},
#   'face_confidence': 0.96,
#   'age': 25,
#   'gender': {'Woman': np.float32(58.673214), 'Man': np.float32(41.326786)},
#   'dominant_gender': 'Woman',
#   'race': {'asian': np.float32(1.3231316),
#    'indian': np.float32(1.77255),
#    'black': np.float32(0.302596),
#    'white': np.float32(62.412155),
#    'middle eastern': np.float32(20.435421),
#    'latino hispanic': np.float32(13.754146)},
#   'dominant_race': 'white'}]

# %%
embedding_objs = DeepFace.represent(img_path_source)
#embedding_objs

# %%
len(embedding_objs)
# Out:
# 2

# %%
embedding_objs[0].keys(),embedding_objs[1].keys()
# Out:
# (dict_keys(['embedding', 'facial_area', 'face_confidence']),
#  dict_keys(['embedding', 'facial_area', 'face_confidence']))

# %%
embedding_objs[0]["face_confidence"],embedding_objs[1]["face_confidence"]
# Out:
# (0.92, 0.96)

# %%
embedding = embedding_objs[0]["embedding"]
plt.plot(embedding)
plt.title("Embedding Vector")
plt.xlabel("Index")
plt.ylabel("Value")
plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
DeepFace.stream(db_path = "Dataset")
# Out:
# 25-10-10 12:11:09 - Age model is just built
# 25-10-10 12:11:09 - Gender model is just built
# 25-10-10 12:11:09 - Emotion model is just built
# 25-10-10 12:11:09 - VGG-Face is built
# 25-10-10 12:11:17 - freezed
# 25-10-10 12:11:22 - Freeze released
# 25-10-10 12:11:24 - freezed
# 25-10-10 12:11:29 - Freeze released
# 25-10-10 12:11:30 - freezed
# 25-10-10 12:11:35 - Freeze released
# 25-10-10 12:11:37 - freezed
# 25-10-10 12:11:42 - Freeze released
# 25-10-10 12:11:43 - freezed
# 25-10-10 12:11:48 - Freeze released
# 25-10-10 12:11:49 - freezed
# 25-10-10 12:11:54 - Freeze released
# 25-10-10 12:11:55 - freezed

# %%
folder_path = "Parejas"
img1_path = f"{folder_path}/img0.jpg"
img1 = DeepFace.extract_faces(img1_path)

# %%
len(img1)
# Out:
# 3

# %%
img1[0]["confidence"],img1[1]["confidence"],img1[2]["confidence"]
# Out:
# (0.92, 0.97, 0.91)

# %%
fig = plt.figure(figsize=(10, 10))

plt.subplot(1, 2, 1)
plt.imshow(img1[1]["face"])

plt.subplot(1, 2, 2)
plt.imshow(img1[2]["face"])

# %%
plt.imshow(img1[0]["face"])

# %%
img_org = plt.imread(img1_path)
plt.imshow(img_org)
